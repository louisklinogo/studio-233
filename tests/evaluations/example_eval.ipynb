// %% [markdown]
// # Sample Evaluation
//
// This notebook demonstrates how to evaluate your agent using LangWatch and LLM-as-a-judge patterns.

// %%
# TODO: Add your evaluation code here using LangWatch SDK
# Refer to https://docs.langwatch.ai/llm-evaluation/offline/code/evaluation-api for documentation
